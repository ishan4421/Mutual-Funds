# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/clean-mutual-fund/Clean_Mutual_fund Data.csv

# %%
data = pd.read_csv("/kaggle/input/clean-mutual-fund/Clean_Mutual_fund Data.csv")

# %%
data
# Out:
#                                AMC  \
# 0              360 one mutual fund
# 1              360 one mutual fund
# 2              360 one mutual fund
# 3              360 one mutual fund
# 4              360 one mutual fund
# ...                            ...
# 1388  whiteoak capital mutual fund
# 1389  whiteoak capital mutual fund
# 1390  whiteoak capital mutual fund
# 1391  whiteoak capital mutual fund
# 1392  whiteoak capital mutual fund
#
#                                          Fund Name  Morning star rating  \
# 0                    360 ONE Balanced Hybrid Reg-G                  0.0
# 1                       360 ONE Dynamic Bond Reg-G                  4.0
# 2      360 ONE ELSS Tax Saver Nifty 50 Index Reg-G                  0.0
# 3                           360 ONE FlexiCap Reg-G                  0.0
# 4                     360 ONE Focused Equity Reg-G                  4.0
# ...                                            ...                  ...
# ...

# %%
data.sort_values(by = "Morning star rating",ascending = False).head(20)
# Out:
#                                     AMC  \
# 999            nippon india mutual fund
# 60    aditya birla sun life mutual fund
# 70    aditya birla sun life mutual fund
# 285      baroda bnp paribas mutual fund
# 517                    hdfc mutual fund
# 135                    axis mutual fund
# 66    aditya birla sun life mutual fund
# 739            jm financial mutual fund
# 1312                    uti mutual fund
# 1060             pgim india mutual fund
# 1315                    uti mutual fund
# 1143                    sbi mutual fund
# 1068             pgim india mutual fund
# 263      baroda bnp paribas mutual fund
# 1070                  quant mutual fund
# 1071                  quant mutual fund
# 715                 invesco mutual fund
# 1077                  quant mutual fund
# 1080                  quant mutual fund
# 1145                    sbi mutual fund
#
#                                         Fund Name  Morning star rating  \
# ...

# %%
data[(data["Morning star rating"] > 4.0) & (data["Value Research rating"] > 4.0)]
# Out:
#                                     AMC  \
# 60    aditya birla sun life mutual fund
# 66    aditya birla sun life mutual fund
# 135                    axis mutual fund
# 245           bank of india mutual fund
# 252           bank of india mutual fund
# 327           canara robeco mutual fund
# 478                    hdfc mutual fund
# 561                    hsbc mutual fund
# 596        icici prudential mutual fund
# 599        icici prudential mutual fund
# 610        icici prudential mutual fund
# 616        icici prudential mutual fund
# 625        icici prudential mutual fund
# 1039                  ppfas mutual fund
# 1070                  quant mutual fund
# 1077                  quant mutual fund
# 1080                  quant mutual fund
# 1084                  quant mutual fund
# 1088                  quant mutual fund
# 1094                  quant mutual fund
# 1110                    sbi mutual fund
# 1138                    sbi mutual fund
# ...

# %%
data[(data["3 Year Return"] > data["3 Year Return"].mean()) & (data["1 Year return"] > data["1 Year return"].mean())]
# Out:
#                                     AMC  \
# 4                   360 one mutual fund
# 9     aditya birla sun life mutual fund
# 10    aditya birla sun life mutual fund
# 30    aditya birla sun life mutual fund
# 31    aditya birla sun life mutual fund
# ...                                 ...
# 1361                    uti mutual fund
# 1368                    uti mutual fund
# 1372                    uti mutual fund
# 1373                    uti mutual fund
# 1376                    uti mutual fund
#
#                                       Fund Name  Morning star rating  \
# 4                  360 ONE Focused Equity Reg-G                  4.0
# 9     Aditya Birla SL Asset Allocator FoF Reg-G                  3.0
# 10     Aditya Birla SL Balanced Advantage Reg-G                  3.0
# 30          Aditya Birla SL Digital India Reg-G                  0.0
# 31         Aditya Birla SL Dividend Yield Reg-G                  3.0
# ...

# %%
data[(data["3 Year Return"] > data["3 Year Return"].median())& (data["1 Year return"] > data["1 Year return"].median())]
# Out:
#                                     AMC  \
# 4                   360 one mutual fund
# 9     aditya birla sun life mutual fund
# 10    aditya birla sun life mutual fund
# 11    aditya birla sun life mutual fund
# 30    aditya birla sun life mutual fund
# ...                                 ...
# 1361                    uti mutual fund
# 1368                    uti mutual fund
# 1372                    uti mutual fund
# 1373                    uti mutual fund
# 1376                    uti mutual fund
#
#                                       Fund Name  Morning star rating  \
# 4                  360 ONE Focused Equity Reg-G                  4.0
# 9     Aditya Birla SL Asset Allocator FoF Reg-G                  3.0
# 10     Aditya Birla SL Balanced Advantage Reg-G                  3.0
# 11    Aditya Birla SL Banking & Financial Servi                  4.0
# 30          Aditya Birla SL Digital India Reg-G                  0.0
# ...

# %%
data["AMC"].unique()
# Out:
# array(['360 one mutual fund', 'aditya birla sun life mutual fund',
#        'axis mutual fund', 'bajaj finserv mutual fund',
#        'bandhan mutual fund', 'bank of india mutual fund',
#        'baroda bnp paribas mutual fund', 'edelweiss mutual fund',
#        'canara robeco mutual fund', 'dsp mutual fund',
#        'franklin templeton mutual fund', 'hdfc mutual fund',
#        'hsbc mutual fund', 'icici prudential mutual fund',
#        'navi mutual fund', 'whiteoak capital mutual fund',
#        'invesco mutual fund', 'jm financial mutual fund',
#        'kotak mahindra mutual fund', 'lic mutual fund',
#        'mahindra manulife mutual fund', 'mirae asset mutual fund',
#        'motilal oswal mutual fund', 'nippon india mutual fund',
#        'ppfas mutual fund', 'pgim india mutual fund', 'quant mutual fund',
#        'samco mutual fund', 'sbi mutual fund', 'sundaram mutual fund',
#        'tata mutual fund', 'taurus mutual fund', 'union mutual fund',
# ...

# %%
data[["AMC","3 Year Return","1 Year return"]].groupby(by = "AMC").mean().sort_values(by = "3 Year Return", ascending=False)
# Out:
#                                    3 Year Return  1 Year return
# AMC
# taurus mutual fund                   1755.111111    3472.666667
# bank of india mutual fund            1383.173913    2433.913043
# jm financial mutual fund             1333.000000    2518.428571
# quant mutual fund                    1189.111111    3599.370370
# lic mutual fund                      1173.375000    2753.437500
# icici prudential mutual fund         1110.934066    2806.065934
# nippon india mutual fund             1106.450704    2155.450704
# invesco mutual fund                  1077.025000    2556.475000
# franklin templeton mutual fund       1037.564103    2160.615385
# sbi mutual fund                      1006.104478    2144.955224
# mahindra manulife mutual fund         968.772727    2516.500000
# canara robeco mutual fund             939.310345    2142.586207
# ppfas mutual fund                     911.666667    1545.666667
# union mutual fund                     906.695652    2068.000000
# ...

# %%
rating_df = data[(data["Morning star rating"] > 4.0) & (data["Value Research rating"] > 4.0)]

# %%
rating_df
# Out:
#                                     AMC  \
# 60    aditya birla sun life mutual fund
# 66    aditya birla sun life mutual fund
# 135                    axis mutual fund
# 245           bank of india mutual fund
# 252           bank of india mutual fund
# 327           canara robeco mutual fund
# 478                    hdfc mutual fund
# 561                    hsbc mutual fund
# 596        icici prudential mutual fund
# 599        icici prudential mutual fund
# 610        icici prudential mutual fund
# 616        icici prudential mutual fund
# 625        icici prudential mutual fund
# 1039                  ppfas mutual fund
# 1070                  quant mutual fund
# 1077                  quant mutual fund
# 1080                  quant mutual fund
# 1084                  quant mutual fund
# 1088                  quant mutual fund
# 1094                  quant mutual fund
# 1110                    sbi mutual fund
# 1138                    sbi mutual fund
# ...

# %%
rating_df.shape
# Out:
# (26, 13)

# %%
rating_df.AMC.unique()
# Out:
# array(['aditya birla sun life mutual fund', 'axis mutual fund',
#        'bank of india mutual fund', 'canara robeco mutual fund',
#        'hdfc mutual fund', 'hsbc mutual fund',
#        'icici prudential mutual fund', 'ppfas mutual fund',
#        'quant mutual fund', 'sbi mutual fund', 'sundaram mutual fund',
#        'uti mutual fund'], dtype=object)

# %%
rating_df.sort_values(by = "Category")
# Out:
#                                     AMC  \
# 60    aditya birla sun life mutual fund
# 1143                    sbi mutual fund
# 1347                    uti mutual fund
# 610        icici prudential mutual fund
# 599        icici prudential mutual fund
# 596        icici prudential mutual fund
# 625        icici prudential mutual fund
# 1375                    uti mutual fund
# 327           canara robeco mutual fund
# 66    aditya birla sun life mutual fund
# 135                    axis mutual fund
# 1189               sundaram mutual fund
# 1138                    sbi mutual fund
# 1084                  quant mutual fund
# 1077                  quant mutual fund
# 1080                  quant mutual fund
# 245           bank of india mutual fund
# 478                    hdfc mutual fund
# 1039                  ppfas mutual fund
# 1110                    sbi mutual fund
# 616        icici prudential mutual fund
# 252           bank of india mutual fund
# ...
